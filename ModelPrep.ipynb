# %%
import DataPrep

# %%
DataPrep.TickerIntoTensor()
# Out:
# (array([[[3.09577038e-04],
#          [2.83417248e-04],
#          [2.48533732e-04],
#          ...,
#          [2.72269738e-04],
#          [2.56185122e-04],
#          [2.60537294e-04]],
#
#         [[2.83417248e-04],
#          [2.48533732e-04],
#          [2.59433553e-04],
#          ...,
#          [2.60346277e-04],
#          [2.62051548e-04],
#          [2.64425544e-04]],
#
#         [[2.48533732e-04],
#          [2.59433553e-04],
#          [2.72517238e-04],
#          ...,
#          [2.66307990e-04],
#          [2.65962397e-04],
#          [2.54704766e-04]],
#
#         ...,
#
#         [[2.78138553e-01],
#          [2.81889980e-01],
#          [2.89392928e-01],
#          ...,
#          [3.35563802e-01],
#          [3.19708081e-01],
#          [3.32612451e-01]],
#
#         [[2.81889980e-01],
#          [2.89392928e-01],
#          [2.88976086e-01],
#          ...,
#          [3.24901025e-01],
#          [3.34545610e-01],
#          [3.21817878e-01]],
#
# ...
